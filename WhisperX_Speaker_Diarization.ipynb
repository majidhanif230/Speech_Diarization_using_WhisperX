# %% [markdown]
# # **Install and import necessary libraries**

# %%
# !pip install --q git+https://github.com/m-bain/whisperx.git
import whisperx
import gc
import pprint

# Pretty print function for inspecting data
pp = pprint.PrettyPrinter(indent=2)
# Out:
#   Preparing metadata (setup.py) ... done
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/core/io.py:43: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("soundfile")

# %% [markdown]
# # **Set device and batch size**

# %%
device = "cuda"
batch_size = 4  # Reduce if low on GPU memory
compute_type = "float16"  # Change to "int8" if low on GPU memory (may reduce accuracy)

# %% [markdown]
# # **Load Audio**

# %%
audio_file = "/content/multi.wav"
audio = whisperx.load_audio(audio_file)

# %% [markdown]
# # **Load Model**

# %%
model = whisperx.load_model("large-v2", device, compute_type=compute_type)
# Out:
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# No language specified, language will be first be detected for each audio file (increases inference time).
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.3.1+cu121. Bad things might happen unless you revert torch to 1.x.

# %% [markdown]
# # **Transcribe the audio**

# %%
result = model.transcribe(audio, batch_size=batch_size)
print("Transcription segments (before alignment):")
pp.pprint(result["segments"])
# Out:
# Detected language: en (1.00) in first 30s of audio...
# Transcription segments (before alignment):
# [ { 'end': 28.507,
#     'start': 0.52,
#     'text': ' Okay, so you guys are upset because the Collider thing disproved '
#             "your theories? It's worse than that. It hasn't found anything in "
#             "years, so we don't know if we're right, we don't know if we're "
#             "wrong, we don't know where to go next. All I know is it looks "
#             'like I tongue-kissed Avatar. Come on, you guys are physicists. '
#             "Okay, you're always gonna be physicists. And sure, sometimes the "
#             "physics is hard, but isn't that what makes it boring?"},
#   { 'end': 58.422,
#     'start': 30.265,
#     'text': " Hey. We're here. What's going on? Okay, as far as I can see, "
#             "science is dead because Leonard killed it. And I don't know who "
#             'the Romulans are, but those guys know how to party. So what do '
#             "you want us to do? I don't know. You're scientists. Cheer them "
#             'up. Cheer them up? Do you even know what a scientist is? But we '
#             "don't need to be cheered up. It just turns out that physics is "
#             'exactly like Lost. Started out great and turns out just a big old '
#             'waste of time.'},
#   { 'end': 68.524,
#     'start': 60.213,
#     'text': ' Boo-hoo. You know what you sound like? Babies. Two whiny babies. '
#             "There's nothing worse than being stuck with two whiny babies."},
#   { 'end': 113.2,
#     'start': 83.951,
#     'text': " Oh, my God, I'm gonna have two babies. No, no, no, no, no, no. "
#             "Babies are great. You're lucky to have two babies. I mean, look "
#             "at me. I'm all alone. I'm never gonna have babies. Because you "
#             "can't make a baby watching Netflix with your dog. Thanks for "
#             "coming. Physics is all we're cut out for."},
#   { 'end': 141.817,
#     'start': 114.138,
#     'text': " If we weren't physicists, what would we be? I don't know. "
#             "Popular? It's fine. I don't need to be a theoretical physicist. "
#             "There's lots of things I could use this brain for. I could be an "
#             "accountant for the mob. I could guess people's weight at the "
#             'fair. Okay, this is getting silly. Is it? 180.'},
#   { 'end': 174.292,
#     'start': 145.606,
#     'text': ' Okay, that is enough. Your lives are not wasted. Your careers '
#             'are not at a dead end. You just hit a rough patch. Instead of '
#             'feeling sorry for yourselves, you need to get up and get '
#             "inspired. How? I don't know. You know, when I'm feeling down, I "
#             "go for a run, which is exactly why I'm not 180 pounds, genius. I "
#             'know where we need to go. Are we running there? Because watching '
#             "drunk children run would be the highlight of my life. We're going "
#             'to see Richard Feynman.'},
#   { 'end': 200.111,
#     'start': 174.974,
#     'text': ' Penny, Richard Feynman is an iconic physicist. I know who he is. '
#             'Leonard dressed as him for Halloween last year. I had no idea '
#             "Richard Feynman was dead. Most people don't know. He's actually "
#             "buried right here in Altadena. I'm sure they keep a lid on that "
#             'to avoid traffic jams. Here he is.'},
#   { 'end': 217.705,
#     'start': 200.879,
#     'text': " Oh, wow. He's buried with his wife. We get it. A lady loved you. "
#             "Quit bragging. Iman was so cool. When I was a kid, I'd put on "
#             'some headphones and crank up one of his lectures and just jam out '
#             'to knowledge.'},
#   { 'end': 247.875,
#     'start': 219.65,
#     'text': ' This guy knew how to live. Taught himself musical instruments. '
#             'Studied Portuguese. Used to give a speech in Brazil. The only '
#             "part of me that's been to Brazil is my bikini line. He did so "
#             'much. And here we are, stuck and letting him down. You know, '
#             "Feynman used to say he didn't do physics for the glory or the "
#             'awards, but just for the fun of it.'},
#   { 'end': 272.944,
#     'start': 249.735,
#     'text': " You're right. Physics is only dead when we stop being excited "
#             "about it. Even beyond the grave, he's imparting wisdom. Um, I'm "
#             'the one who remembered it. Give me the bottle. It might be a '
#             'little corny, but I say we pour one out for all the science '
#             "homies who came before us. I love that. Let's do it."},
#   { 'end': 289.462,
#     'start': 279.087,
#     'text': ' Here comes some more. We got to see him run.'}]

# %% [markdown]
# # **Align the Whisper output**

# %%
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)
result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)

# %% [markdown]
# # **Initialize the diarization pipeline**

# %%
diarize_model = whisperx.DiarizationPipeline(model_name='pyannote/speaker-diarization-3.1',
                                             use_auth_token="Add your key",
                                             device=device)

# %% [markdown]
# # **Perform speaker diarization**

# %%
diarize_segments = diarize_model(audio, min_speakers=2, max_speakers=10)
print("Diarization segments:")
pp.pprint(diarize_segments)
print("Unique speakers detected:")
print(diarize_segments.speaker.unique())
# Out:
# Diarization segments:
#                                segment label     speaker       start  \
# 0    [ 00:00:00.687 -->  00:00:05.696]     A  SPEAKER_00    0.687606
# 1    [ 00:00:05.696 -->  00:00:11.825]     B  SPEAKER_03    5.696095
# 2    [ 00:00:12.147 -->  00:00:15.118]     C  SPEAKER_02   12.147708
# 3    [ 00:00:17.971 -->  00:00:27.580]     D  SPEAKER_00   17.971138
# 4    [ 00:00:28.582 -->  00:00:29.125]     E  SPEAKER_01   28.582343
# ..                                 ...   ...         ...         ...
# 102  [ 00:04:39.074 -->  00:04:40.144]    CY  SPEAKER_02  279.074703
# 103  [ 00:04:42.996 -->  00:04:43.370]    CZ  SPEAKER_00  282.996604
# 104  [ 00:04:43.505 -->  00:04:43.539]    DA  SPEAKER_00  283.505942
# 105  [ 00:04:45.203 -->  00:04:48.955]    DB  SPEAKER_00  285.203735
# 106  [ 00:04:49.006 -->  00:04:49.465]    DC  SPEAKER_00  289.006791
#
#             end
# 0      5.696095
# 1     11.825127
# 2     15.118846
# 3     27.580645
# 4     29.125637
# ..          ...
# 102  280.144312
# 103  283.370119
# 104  283.539898
# 105  288.955857
# 106  289.465195
#
# [107 rows x 5 columns]
# Unique speakers detected:
# ['SPEAKER_00' 'SPEAKER_03' 'SPEAKER_02' 'SPEAKER_01' 'SPEAKER_04'
#  'SPEAKER_05']

# %% [markdown]
# # **Assign speaker IDs to transcription segments**

# %%
result = whisperx.assign_word_speakers(diarize_segments, result)
print("Transcription segments with speaker IDs:")
pp.pprint(result["segments"])
# Out:
# Transcription segments with speaker IDs:
# [ { 'end': 5.101,
#     'speaker': 'SPEAKER_00',
#     'start': 0.8,
#     'text': ' Okay, so you guys are upset because the Collider thing disproved '
#             'your theories?',
#     'words': [ { 'end': 1.1,
#                  'score': 0.617,
#                  'speaker': 'SPEAKER_00',
#                  'start': 0.8,
#                  'word': 'Okay,'},
#                { 'end': 1.26,
#                  'score': 0.314,
#                  'speaker': 'SPEAKER_00',
#                  'start': 1.16,
#                  'word': 'so'},
#                { 'end': 1.48,
#                  'score': 0.764,
#                  'speaker': 'SPEAKER_00',
#                  'start': 1.34,
#                  'word': 'you'},
#                { 'end': 1.66,
#                  'score': 0.475,
#                  'speaker': 'SPEAKER_00',
#                  'start': 1.5,
#                  'word': 'guys'},
#                { 'end': 1.8,
#                  'score': 0.751,
#                  'speaker': 'SPEAKER_00',
#                  'start': 1.7,
#                  'word': 'are'},
#                { 'end': 2.3,
#                  'score': 0.863,
#                  'speaker': 'SPEAKER_00',
#                  'start': 1.86,
#                  'word': 'upset'},
#                { 'end': 2.681,
#                  'score': 0.83,
#                  'speaker': 'SPEAKER_00',
#                  'start': 2.38,
#                  'word': 'because'},
#                { 'end': 2.821,
#                  'score': 0.846,
#                  'speaker': 'SPEAKER_00',
#                  'start': 2.721,
#                  'word': 'the'},
#                { 'end': 3.421,
#                  'score': 0.794,
#                  'speaker': 'SPEAKER_00',
#                  'start': 2.881,
#                  'word': 'Collider'},
#                { 'end': 3.721,
#                  'score': 0.849,
#                  'speaker': 'SPEAKER_00',
#                  'start': 3.481,
#                  'word': 'thing'},
#                { 'end': 4.321,
#                  'score': 0.919,
#                  'speaker': 'SPEAKER_00',
#                  'start': 3.761,
#                  'word': 'disproved'},
#                { 'end': 4.501,
#                  'score': 0.959,
#                  'speaker': 'SPEAKER_00',
#                  'start': 4.361,
#                  'word': 'your'},
#                { 'end': 5.101,
#                  'score': 0.852,
#                  'speaker': 'SPEAKER_00',
#                  'start': 4.601,
#                  'word': 'theories?'}]},
#   { 'end': 6.522,
#     'speaker': 'SPEAKER_03',
#     'start': 5.501,
#     'text': "It's worse than that.",
#     'words': [ { 'end': 5.621,
#                  'score': 0.769,
#                  'speaker': 'SPEAKER_00',
#                  'start': 5.501,
#                  'word': "It's"},
#                { 'end': 6.041,
#                  'score': 0.634,
#                  'speaker': 'SPEAKER_03',
#                  'start': 5.741,
#                  'word': 'worse'},
#                { 'end': 6.241,
#                  'score': 0.739,
#                  'speaker': 'SPEAKER_03',
#                  'start': 6.101,
#                  'word': 'than'},
#                { 'end': 6.522,
#                  'score': 0.978,
#                  'speaker': 'SPEAKER_03',
#                  'start': 6.281,
#                  'word': 'that.'}]},
#   { 'end': 11.683,
#     'speaker': 'SPEAKER_03',
#     'start': 6.542,
#     'text': "It hasn't found anything in years, so we don't know if we're "
#             "right, we don't know if we're wrong, we don't know where to go "
#             'next.',
#     'words': [ { 'end': 6.582,
#                  'score': 0.0,
#                  'speaker': 'SPEAKER_03',
#                  'start': 6.542,
#                  'word': 'It'},
#                { 'end': 6.922,
#                  'score': 0.876,
#                  'speaker': 'SPEAKER_03',
#                  'start': 6.742,
#                  'word': "hasn't"},
#                { 'end': 7.122,
#                  'score': 0.707,
#                  'speaker': 'SPEAKER_03',
#                  'start': 6.962,
#                  'word': 'found'},
#                { 'end': 7.722,
#                  'score': 0.853,
#                  'speaker': 'SPEAKER_03',
#                  'start': 7.282,
#                  'word': 'anything'},
#                { 'end': 7.822,
#                  'score': 0.768,
#                  'speaker': 'SPEAKER_03',
#                  'start': 7.762,
#                  'word': 'in'},
#                { 'end': 8.202,
#                  'score': 0.688,
#                  'speaker': 'SPEAKER_03',
#                  'start': 7.862,
#                  'word': 'years,'},
#                { 'end': 8.342,
#                  'score': 0.996,
#                  'speaker': 'SPEAKER_03',
#                  'start': 8.242,
#                  'word': 'so'},
#                { 'end': 8.442,
#                  'score': 0.997,
#                  'speaker': 'SPEAKER_03',
#                  'start': 8.382,
#                  'word': 'we'},
#                { 'end': 8.622,
#                  'score': 0.802,
#                  'speaker': 'SPEAKER_03',
#                  'start': 8.482,
#                  'word': "don't"},
#                { 'end': 8.862,
#                  'score': 0.716,
#                  'speaker': 'SPEAKER_03',
#                  'start': 8.642,
#                  'word': 'know'},
#                { 'end': 8.922,
#                  'score': 0.0,
#                  'speaker': 'SPEAKER_03',
#                  'start': 8.882,
#                  'word': 'if'},
#                { 'end': 9.302,
#                  'score': 0.925,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.142,
#                  'word': "we're"},
#                { 'end': 9.542,
#                  'score': 0.647,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.342,
#                  'word': 'right,'},
#                { 'end': 9.642,
#                  'score': 0.73,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.562,
#                  'word': 'we'},
#                { 'end': 9.762,
#                  'score': 0.646,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.662,
#                  'word': "don't"},
#                { 'end': 9.862,
#                  'score': 0.229,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.782,
#                  'word': 'know'},
#                { 'end': 9.922,
#                  'score': 0.002,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.882,
#                  'word': 'if'},
#                { 'end': 10.042,
#                  'score': 0.0,
#                  'speaker': 'SPEAKER_03',
#                  'start': 9.942,
#                  'word': "we're"},
#                { 'end': 10.382,
#                  'score': 0.743,
#                  'speaker': 'SPEAKER_03',
#                  'start': 10.082,
#                  'word': 'wrong,'},
#                { 'end': 10.502,
#                  'score': 0.806,
#                  'speaker': 'SPEAKER_03',
#                  'start': 10.422,
#                  'word': 'we'},
#                { 'end': 10.643,
#                  'score': 0.698,
#                  'speaker': 'SPEAKER_03',
#                  'start': 10.523,
#                  'word': "don't"},
#                { 'end': 10.743,
#                  'score': 0.093,
#                  'speaker': 'SPEAKER_03',
#                  'start': 10.663,
#                  'word': 'know'},
#                { 'end': 10.983,
#                  'score': 0.476,
#                  'speaker': 'SPEAKER_03',
#                  'start': 10.783,
#                  'word': 'where'},
#                { 'end': 11.083,
#                  'score': 0.496,
#                  'speaker': 'SPEAKER_03',
#                  'start': 11.003,
#                  'word': 'to'},
#                { 'end': 11.323,
#                  'score': 0.992,
#                  'speaker': 'SPEAKER_03',
#                  'start': 11.123,
#                  'word': 'go'},
#                { 'end': 11.683,
#                  'score': 0.928,
#                  'speaker': 'SPEAKER_03',
#                  'start': 11.363,
#                  'word': 'next.'}]},
#   { 'end': 15.004,
#     'speaker': 'SPEAKER_02',
#     'start': 12.223,
#     'text': 'All I know is it looks like I tongue-kissed Avatar.',
#     'words': [ { 'end': 12.363,
#                  'score': 0.476,
#                  'speaker': 'SPEAKER_02',
#                  'start': 12.223,
#                  'word': 'All'},
#                { 'end': 12.503,
#                  'score': 0.67,
#                  'speaker': 'SPEAKER_02',
#                  'start': 12.443,
#                  'word': 'I'},
#                { 'end': 12.683,
#                  'score': 0.716,
#                  'speaker': 'SPEAKER_02',
#                  'start': 12.543,
#                  'word': 'know'},
#                { 'end': 12.843,
#                  'score': 0.605,
#                  'speaker': 'SPEAKER_02',
#                  'start': 12.763,
#                  'word': 'is'},
#                { 'end': 12.963,
#                  'score': 0.756,
#                  'speaker': 'SPEAKER_02',
#                  'start': 12.903,
#                  'word': 'it'},
#                { 'end': 13.163,
#                  'score': 0.695,
#                  'speaker': 'SPEAKER_02',
#                  'start': 12.983,
#                  'word': 'looks'},
#                { 'end': 13.323,
#                  'score': 0.666,
#                  'speaker': 'SPEAKER_02',
#                  'start': 13.183,
#                  'word': 'like'},
#                { 'end': 13.423,
#                  'score': 0.001,
#                  'speaker': 'SPEAKER_02',
#                  'start': 13.383,
#                  'word': 'I'},
#                { 'end': 14.183,
#                  'score': 0.654,
#                  'speaker': 'SPEAKER_02',
#                  'start': 13.543,
#                  'word': 'tongue-kissed'},
#                { 'end': 15.004,
#                  'score': 0.812,
#                  'speaker': 'SPEAKER_02',
#                  'start': 14.383,
#                  'word': 'Avatar.'}]},
#   { 'end': 20.105,
#     'speaker': 'SPEAKER_00',
#     'start': 18.024,
#     'text': 'Come on, you guys are physicists.',
#     'words': [ { 'end': 18.204,
#                  'score': 0.626,
#                  'speaker': 'SPEAKER_00',
#                  'start': 18.024,
#                  'word': 'Come'},
#                { 'end': 18.705,
#                  'score': 0.72,
#                  'speaker': 'SPEAKER_00',
#                  'start': 18.545,
#                  'word': 'on,'},
#                { 'end': 18.845,
#                  'score': 0.871,
#                  'speaker': 'SPEAKER_00',
#                  'start': 18.745,
#                  'word': 'you'},
#                { 'end': 19.065,
#                  'score': 0.411,
#                  'speaker': 'SPEAKER_00',
#                  'start': 18.885,
#                  'word': 'guys'},
#                { 'end': 19.245,
#                  'score': 0.607,
#                  'speaker': 'SPEAKER_00',
#                  'start': 19.125,
#                  'word': 'are'},
#                { 'end': 20.105,
#                  'score': 0.764,
#                  'speaker': 'SPEAKER_00',
#                  'start': 19.345,
#                  'word': 'physicists.'}]},
#   { 'end': 22.305,
#     'speaker': 'SPEAKER_00',
#     'start': 20.245,
#     'text': "Okay, you're always gonna be physicists.",
#     'words': [ { 'end': 20.445,
#                  'score': 0.504,
#                  'speaker': 'SPEAKER_00',
#                  'start': 20.245,
#                  'word': 'Okay,'},
#                { 'end': 20.645,
#                  'score': 0.835,
#                  'speaker': 'SPEAKER_00',
#                  'start': 20.465,
#                  'word': "you're"},
#                { 'end': 20.925,
#                  'score': 0.668,
#                  'speaker': 'SPEAKER_00',
#                  'start': 20.665,
#                  'word': 'always'},
#                { 'end': 21.205,
#                  'score': 0.494,
#                  'speaker': 'SPEAKER_00',
#                  'start': 20.965,
#                  'word': 'gonna'},
#                { 'end': 21.605,
#                  'score': 0.899,
#                  'speaker': 'SPEAKER_00',
#                  'start': 21.285,
#                  'word': 'be'},
#                { 'end': 22.305,
#                  'score': 0.756,
#                  'speaker': 'SPEAKER_00',
#                  'start': 21.645,
#                  'word': 'physicists.'}]},
#   { 'end': 27.467,
#     'speaker': 'SPEAKER_00',
#     'start': 22.445,
#     'text': "And sure, sometimes the physics is hard, but isn't that what "
#             'makes it boring?',
#     'words': [ { 'end': 22.546,
#                  'score': 0.799,
#                  'speaker': 'SPEAKER_00',
#                  'start': 22.445,
#                  'word': 'And'},
#                { 'end': 23.126,
#                  'score': 0.698,
#                  'speaker': 'SPEAKER_00',
#                  'start': 22.706,
#                  'word': 'sure,'},
#                { 'end': 23.686,
#                  'score': 0.852,
#                  'speaker': 'SPEAKER_00',
#                  'start': 23.206,
#                  'word': 'sometimes'},
#                { 'end': 23.826,
#                  'score': 0.826,
#                  'speaker': 'SPEAKER_00',
#                  'start': 23.746,
#                  'word': 'the'},
#                { 'end': 24.246,
#                  'score': 0.906,
#                  'speaker': 'SPEAKER_00',
#                  'start': 23.886,
#                  'word': 'physics'},
#                { 'end': 24.466,
#                  'score': 0.751,
#                  'speaker': 'SPEAKER_00',
#                  'start': 24.366,
#                  'word': 'is'},
#                { 'end': 24.866,
#                  'score': 0.634,
#                  'speaker': 'SPEAKER_00',
#                  'start': 24.546,
#                  'word': 'hard,'},
#                { 'end': 25.286,
#                  'score': 0.881,
#                  'speaker': 'SPEAKER_00',
#                  'start': 25.166,
#                  'word': 'but'},
#                { 'end': 25.626,
#                  'score': 0.745,
#                  'speaker': 'SPEAKER_00',
#                  'start': 25.406,
#                  'word': "isn't"},
#                { 'end': 25.986,
#                  'score': 0.807,
#                  'speaker': 'SPEAKER_00',
#                  'start': 25.746,
#                  'word': 'that'},
#                { 'end': 26.266,
#                  'score': 0.71,
#                  'speaker': 'SPEAKER_00',
#                  'start': 26.106,
#                  'word': 'what'},
#                { 'end': 26.647,
#                  'score': 0.827,
#                  'speaker': 'SPEAKER_00',
#                  'start': 26.366,
#                  'word': 'makes'},
#                { 'end': 26.807,
#                  'score': 0.938,
#                  'speaker': 'SPEAKER_00',
#                  'start': 26.747,
#                  'word': 'it'},
#                { 'end': 27.467,
#                  'score': 0.891,
#                  'speaker': 'SPEAKER_00',
#                  'start': 26.987,
#                  'word': 'boring?'}]},
#   { 'end': 30.565,
#     'speaker': 'SPEAKER_00',
#     'start': 30.305,
#     'text': ' Hey.',
#     'words': [ { 'end': 30.565,
#                  'score': 0.712,
#                  'speaker': 'SPEAKER_00',
#                  'start': 30.305,
#                  'word': 'Hey.'}]},
#   { 'end': 31.346,
#     'speaker': 'SPEAKER_04',
#     'start': 30.985,
#     'text': "We're here.",
#     'words': [ { 'end': 31.126,
#                  'score': 0.619,
#                  'speaker': 'SPEAKER_04',
#                  'start': 30.985,
#                  'word': "We're"},
#                { 'end': 31.346,
#                  'score': 0.809,
#                  'speaker': 'SPEAKER_04',
#                  'start': 31.186,
#                  'word': 'here.'}]},
#   { 'end': 32.466,
#     'speaker': 'SPEAKER_04',
#     'start': 31.366,
#     'text': "What's going on?",
#     'words': [ { 'end': 31.926,
#                  'score': 0.274,
#                  'speaker': 'SPEAKER_04',
#                  'start': 31.366,
#                  'word': "What's"},
#                { 'end': 32.146,
#                  'score': 0.407,
#                  'speaker': 'SPEAKER_04',
#                  'start': 31.966,
#                  'word': 'going'},
#                { 'end': 32.466,
#                  'score': 0.782,
#                  'speaker': 'SPEAKER_04',
#                  'start': 32.326,
#                  'word': 'on?'}]},
#   { 'end': 36.729,
#     'speaker': 'SPEAKER_00',
#     'start': 32.787,
#     'text': 'Okay, as far as I can see, science is dead because Leonard killed '
#             'it.',
#     'words': [ { 'end': 33.027,
#                  'score': 0.524,
#                  'speaker': 'SPEAKER_00',
#                  'start': 32.787,
#                  'word': 'Okay,'},
#                { 'end': 33.107,
#                  'score': 0.686,
#                  'speaker': 'SPEAKER_00',
#                  'start': 33.047,
#                  'word': 'as'},
#                { 'end': 33.327,
#                  'score': 0.886,
#                  'speaker': 'SPEAKER_00',
#                  'start': 33.187,
#                  'word': 'far'},
#                { 'end': 33.447,
#                  'score': 0.794,
#                  'speaker': 'SPEAKER_00',
#                  'start': 33.367,
#                  'word': 'as'},
#                { 'end': 33.547,
#                  'score': 0.946,
#                  'speaker': 'SPEAKER_00',
#                  'start': 33.487,
#                  'word': 'I'},
#                { 'end': 33.747,
#                  'score': 0.905,
#                  'speaker': 'SPEAKER_00',
#                  'start': 33.587,
#                  'word': 'can'},
#                { 'end': 34.067,
#                  'score': 0.635,
#                  'speaker': 'SPEAKER_00',
#                  'start': 33.787,
#                  'word': 'see,'},
#                { 'end': 35.028,
#                  'score': 0.909,
#                  'speaker': 'SPEAKER_00',
#                  'start': 34.708,
#                  'word': 'science'},
#                { 'end': 35.188,
#                  'score': 0.46,
#                  'speaker': 'SPEAKER_00',
#                  'start': 35.088,
#                  'word': 'is'},
#                { 'end': 35.568,
#                  'score': 0.735,
#                  'speaker': 'SPEAKER_00',
#                  'start': 35.268,
#                  'word': 'dead'},
#                { 'end': 35.948,
#                  'score': 0.272,
#                  'speaker': 'SPEAKER_00',
#                  'start': 35.588,
#                  'word': 'because'},
#                { 'end': 36.269,
#                  'score': 0.724,
#                  'speaker': 'SPEAKER_00',
#                  'start': 35.988,
#                  'word': 'Leonard'},
#                { 'end': 36.609,
#                  'score': 0.827,
#                  'speaker': 'SPEAKER_00',
#                  'start': 36.329,
#                  'word': 'killed'},
#                { 'end': 36.729,
#                  'score': 0.751,
#                  'speaker': 'SPEAKER_00',
#                  'start': 36.669,
#                  'word': 'it.'}]},
#   { 'end': 40.611,
#     'speaker': 'SPEAKER_00',
#     'start': 37.389,
#     'text': "And I don't know who the Romulans are, but those guys know how to "
#             'party.',
#     'words': [ { 'end': 37.609,
#                  'score': 0.739,
#                  'speaker': 'SPEAKER_00',
#                  'start': 37.389,
#                  'word': 'And'},
#                { 'end': 37.649,
#                  'score': 0.0,
#                  'speaker': 'SPEAKER_00',
#                  'start': 37.629,
#                  'word': 'I'},
#                { 'end': 38.19,
#                  'score': 0.701,
#                  'speaker': 'SPEAKER_00',
#                  'start': 38.03,
#                  'word': "don't"},
#                { 'end': 38.39,
#                  'score': 0.75,
#                  'speaker': 'SPEAKER_00',
#                  'start': 38.27,
#                  'word': 'know'},
#                { 'end': 38.55,
#                  'score': 0.991,
#                  'speaker': 'SPEAKER_00',
#                  'start': 38.45,
#                  'word': 'who'},
#                { 'end': 38.67,
#                  'score': 0.865,
#                  'speaker': 'SPEAKER_00',
#                  'start': 38.59,
#                  'word': 'the'},
#                { 'end': 39.15,
#                  'score': 0.86,
#                  'speaker': 'SPEAKER_00',
#                  'start': 38.71,
#                  'word': 'Romulans'},
#                { 'end': 39.31,
#                  'score': 0.765,
#                  'speaker': 'SPEAKER_00',
#                  'start': 39.23,
#                  'word': 'are,'},
#                { 'end': 39.471,
#                  'score': 0.697,
#                  'speaker': 'SPEAKER_00',
#                  'start': 39.33,
#                  'word': 'but'},
#                { 'end': 39.691,
#                  'score': 0.912,
#                  'speaker': 'SPEAKER_00',
#                  'start': 39.531,
#                  'word': 'those'},
#                { 'end': 39.951,
#                  'score': 0.692,
#                  'speaker': 'SPEAKER_00',
#                  'start': 39.731,
#                  'word': 'guys'},
#                { 'end': 40.111,
#                  'score': 0.759,
#                  'speaker': 'SPEAKER_00',
#                  'start': 39.991,
#                  'word': 'know'},
#                { 'end': 40.211,
#                  'score': 0.892,
#                  'speaker': 'SPEAKER_00',
#                  'start': 40.151,
#                  'word': 'how'},
#                { 'end': 40.271,
#                  'score': 0.619,
#                  'speaker': 'SPEAKER_00',
#                  'start': 40.231,
#                  'word': 'to'},
#                { 'end': 40.611,
#                  'score': 0.879,
#                  'speaker': 'SPEAKER_00',
#                  'start': 40.331,
#                  'word': 'party.'}]},
#   { 'end': 43.593,
#     'speaker': 'SPEAKER_00',
#     'start': 40.631,
#     'text': 'So what do you want us to do?',
#     'words': [ { 'end': 41.532,
#                  'score': 0.874,
#                  'speaker': 'SPEAKER_00',
#                  'start': 40.631,
#                  'word': 'So'},
#                { 'end': 42.953,
#                  'score': 0.539,
#                  'speaker': 'SPEAKER_05',
#                  'start': 42.532,
#                  'word': 'what'},
#                { 'end': 43.073,
#                  'score': 0.166,
#                  'speaker': 'SPEAKER_04',
#                  'start': 42.973,
#                  'word': 'do'},
#                { 'end': 43.153,
#                  'score': 0.48,
#                  'speaker': 'SPEAKER_04',
#                  'start': 43.093,
#                  'word': 'you'},
#                { 'end': 43.273,
#                  'score': 0.874,
#                  'speaker': 'SPEAKER_04',
#                  'start': 43.173,
#                  'word': 'want'},
#                { 'end': 43.353,
#                  'score': 0.54,
#                  'speaker': 'SPEAKER_04',
#                  'start': 43.313,
#                  'word': 'us'},
#                { 'end': 43.453,
#                  'score': 0.694,
#                  'speaker': 'SPEAKER_04',
#                  'start': 43.373,
#                  'word': 'to'},
#                { 'end': 43.593,
#                  'score': 0.834,
#                  'speaker': 'SPEAKER_04',
#                  'start': 43.493,
#                  'word': 'do?'}]},
#   { 'end': 44.153,
#     'speaker': 'SPEAKER_00',
#     'start': 43.813,
#     'text': "I don't know.",
#     'words': [ { 'end': 43.853,
#                  'score': 0.99,
#                  'speaker': 'SPEAKER_00',
#                  'start': 43.813,
#                  'word': 'I'},
#                { 'end': 44.033,
#                  'score': 0.8,
#                  'speaker': 'SPEAKER_00',
#                  'start': 43.893,
#                  'word': "don't"},
#                { 'end': 44.153,
#                  'score': 0.863,
#                  'speaker': 'SPEAKER_00',
#                  'start': 44.053,
#                  'word': 'know.'}]},
#   { 'end': 44.814,
#     'speaker': 'SPEAKER_00',
#     'start': 44.193,
#     'text': "You're scientists.",
#     'words': [ { 'end': 44.333,
#                  'score': 0.698,
#                  'speaker': 'SPEAKER_00',
#                  'start': 44.193,
#                  'word': "You're"},
#                { 'end': 44.814,
#                  'score': 0.779,
#                  'speaker': 'SPEAKER_00',
#                  'start': 44.354,
#                  'word': 'scientists.'}]},
#   { 'end': 45.394,
#     'speaker': 'SPEAKER_00',
#     'start': 44.854,
#     'text': 'Cheer them up.',
#     'words': [ { 'end': 45.054,
#                  'score': 0.919,
#                  'speaker': 'SPEAKER_00',
#                  'start': 44.854,
#                  'word': 'Cheer'},
#                { 'end': 45.174,
#                  'score': 0.982,
#                  'speaker': 'SPEAKER_00',
#                  'start': 45.074,
#                  'word': 'them'},
#                { 'end': 45.394,
#                  'score': 0.738,
#                  'speaker': 'SPEAKER_00',
#                  'start': 45.294,
#                  'word': 'up.'}]},
#   { 'end': 46.975,
#     'speaker': 'SPEAKER_04',
#     'start': 46.055,
#     'text': 'Cheer them up?',
#     'words': [ { 'end': 46.315,
#                  'score': 0.756,
#                  'speaker': 'SPEAKER_04',
#                  'start': 46.055,
#                  'word': 'Cheer'},
#                { 'end': 46.495,
#                  'score': 0.846,
#                  'speaker': 'SPEAKER_04',
#                  'start': 46.355,
#                  'word': 'them'},
#                { 'end': 46.975,
#                  'score': 0.935,
#                  'speaker': 'SPEAKER_04',
#                  'start': 46.875,
#                  'word': 'up?'}]},
#   { 'end': 48.656,
#     'speaker': 'SPEAKER_04',
#     'start': 47.075,
#     'text': 'Do you even know what a scientist is?',
#     'words': [ { 'end': 47.235,
#                  'score': 0.879,
#                  'speaker': 'SPEAKER_04',
#                  'start': 47.075,
#                  'word': 'Do'},
#                { 'end': 47.335,
#                  'score': 0.988,
#                  'speaker': 'SPEAKER_04',
#                  'start': 47.275,
#                  'word': 'you'},
#                { 'end': 47.435,
#                  'score': 0.0,
#                  'speaker': 'SPEAKER_04',
#                  'start': 47.355,
#                  'word': 'even'},
#                { 'end': 47.615,
#                  'score': 0.856,
#                  'speaker': 'SPEAKER_04',
#                  'start': 47.495,
#                  'word': 'know'},
#                { 'end': 47.736,
#                  'score': 0.868,
#                  'speaker': 'SPEAKER_04',
#                  'start': 47.635,
#                  'word': 'what'},
#                { 'end': 47.836,
#                  'score': 0.409,
#                  'speaker': 'SPEAKER_04',
#                  'start': 47.796,
#                  'word': 'a'},
#                { 'end': 48.396,
#                  'score': 0.89,
#                  'speaker': 'SPEAKER_03',
#                  'start': 47.896,
#                  'word': 'scientist'},
#                { 'end': 48.656,
#                  'score': 0.692,
#                  'speaker': 'SPEAKER_03',
#                  'start': 48.516,
#                  'word': 'is?'}]},
#   { 'end': 52.538,
#     'speaker': 'SPEAKER_03',
#     'start': 50.857,
#     'text': "But we don't need to be cheered up.",
#     'words': [ { 'end': 50.978,
#                  'score': 0.947,
#                  'speaker': 'SPEAKER_03',
#                  'start': 50.857,
#                  'word': 'But'},
#                { 'end': 51.098,
#                  'score': 0.982,
#                  'speaker': 'SPEAKER_03',
#                  'start': 51.018,
#                  'word': 'we'},
#                { 'end': 51.318,
#                  'score': 0.634,
#                  'speaker': 'SPEAKER_03',
#                  'start': 51.138,
#                  'word': "don't"},
#                { 'end': 51.538,
#                  'score': 0.734,
#                  'speaker': 'SPEAKER_03',
#                  'start': 51.358,
#                  'word': 'need'},
#                { 'end': 51.638,
#                  'score': 0.484,
#                  'speaker': 'SPEAKER_03',
#                  'start': 51.558,
#                  'word': 'to'},
#                { 'end': 51.778,
#                  'score': 0.844,
#                  'speaker': 'SPEAKER_03',
#                  'start': 51.678,
#                  'word': 'be'},
#                { 'end': 52.278,
#                  'score': 0.715,
#                  'speaker': 'SPEAKER_03',
#                  'start': 51.878,
#                  'word': 'cheered'},
#                { 'end': 52.538,
#                  'score': 0.868,
#                  'speaker': 'SPEAKER_03',
#                  'start': 52.438,
#                  'word': 'up.'}]},
#   { 'end': 55.52,
#     'speaker': 'SPEAKER_03',
#     'start': 52.618,
#     'text': 'It just turns out that physics is exactly like Lost.',
#     'words': [ { 'end': 52.699,
#                  'score': 0.636,
#                  'speaker': 'SPEAKER_03',
#                  'start': 52.618,
#                  'word': 'It'},
#                { 'end': 52.899,
#                  'score': 0.878,
#                  'speaker': 'SPEAKER_03',
#                  'start': 52.759,
#                  'word': 'just'},
#                { 'end': 53.319,
#                  'score': 0.817,
#                  'speaker': 'SPEAKER_03',
#                  'start': 53.079,
#                  'word': 'turns'},
#                { 'end': 53.459,
#                  'score': 0.835,
#                  'speaker': 'SPEAKER_03',
#                  'start': 53.379,
#                  'word': 'out'},
#                { 'end': 53.639,
#                  'score': 0.846,
#                  'speaker': 'SPEAKER_03',
#                  'start': 53.499,
#                  'word': 'that'},
#                { 'end': 54.079,
#                  'score': 0.88,
#                  'speaker': 'SPEAKER_03',
#                  'start': 53.759,
#                  'word': 'physics'},
#                { 'end': 54.239,
#                  'score': 0.666,
#                  'speaker': 'SPEAKER_03',
#                  'start': 54.139,
#                  'word': 'is'},
#                { 'end': 54.76,
#                  'score': 0.81,
#                  'speaker': 'SPEAKER_03',
#                  'start': 54.34,
#                  'word': 'exactly'},
#                { 'end': 55.0,
#                  'score': 0.832,
#                  'speaker': 'SPEAKER_03',
#                  'start': 54.82,
#                  'word': 'like'},
#                { 'end': 55.52,
#                  'score': 0.651,
#                  'speaker': 'SPEAKER_03',
#                  'start': 55.12,
#                  'word': 'Lost.'}]},
#   { 'end': 57.942,
#     'speaker': 'SPEAKER_03',
#     'start': 55.58,
#     'text': 'Started out great and turns out just a big old waste of time.',
#     'words': [ { 'end': 55.86,
#                  'score': 0.911,
#                  'speaker': 'SPEAKER_03',
#                  'start': 55.58,
#                  'word': 'Started'},
#                { 'end': 56.021,
#                  'score': 0.781,
#                  'speaker': 'SPEAKER_03',
#                  'start': 55.9,
#                  'word': 'out'},
#                { 'end': 56.321,
#                  'score': 0.673,
#                  'speaker': 'SPEAKER_03',
#                  'start': 56.081,
#                  'word': 'great'},
#                { 'end': 56.441,
#                  'score': 0.847,
#                  'speaker': 'SPEAKER_03',
#                  'start': 56.361,
#                  'word': 'and'},
#                { 'end': 56.701,
#                  'score': 0.808,
#                  'speaker': 'SPEAKER_03',
#                  'start': 56.521,
#                  'word': 'turns'},
#                { 'end': 56.841,
#                  'score': 0.844,
#                  'speaker': 'SPEAKER_03',
#                  'start': 56.741,
#                  'word': 'out'},
#                { 'end': 56.981,
#                  'score': 0.686,
#                  'speaker': 'SPEAKER_03',
#                  'start': 56.861,
#                  'word': 'just'},
#                { 'end': 57.021,
#                  'score': 0.671,
#                  'speaker': 'SPEAKER_03',
#                  'start': 57.001,
#                  'word': 'a'},
#                { 'end': 57.181,
#                  'score': 0.826,
#                  'speaker': 'SPEAKER_03',
#                  'start': 57.061,
#                  'word': 'big'},
#                { 'end': 57.261,
#                  'score': 0.328,
#                  'speaker': 'SPEAKER_03',
#                  'start': 57.201,
#                  'word': 'old'},
#                { 'end': 57.461,
#                  'score': 0.555,
#                  'speaker': 'SPEAKER_03',
#                  'start': 57.301,
#                  'word': 'waste'},
#                { 'end': 57.581,
#                  'score': 0.502,
#                  'speaker': 'SPEAKER_03',
#                  'start': 57.521,
#                  'word': 'of'},
#                { 'end': 57.942,
#                  'score': 0.588,
#                  'speaker': 'SPEAKER_03',
#                  'start': 57.602,
#                  'word': 'time.'}]},
#   { 'end': 60.654,
#     'speaker': 'SPEAKER_01',
#     'start': 60.233,
#     'text': ' Boo-hoo.',
#     'words': [ { 'end': 60.654,
#                  'score': 0.475,
#                  'speaker': 'SPEAKER_01',
#                  'start': 60.233,
#                  'word': 'Boo-hoo.'}]},
#   { 'end': 61.855,
#     'speaker': 'SPEAKER_05',
#     'start': 61.034,
#     'text': 'You know what you sound like?',
#     'words': [ { 'end': 61.094,
#                  'score': 0.975,
#                  'speaker': 'SPEAKER_05',
#                  'start': 61.034,
#                  'word': 'You'},
#                { 'end': 61.194,
#                  'score': 0.029,
#                  'speaker': 'SPEAKER_05',
#                  'start': 61.114,
#                  'word': 'know'},
#                { 'end': 61.294,
#                  'score': 0.25,
#                  'speaker': 'SPEAKER_05',
#                  'start': 61.214,
#                  'word': 'what'},
#                { 'end': 61.395,
#                  'score': 0.666,
#                  'speaker': 'SPEAKER_05',
#                  'start': 61.314,
#                  'word': 'you'},
#                { 'end': 61.675,
#                  'score': 0.539,
#                  'speaker': 'SPEAKER_05',
#                  'start': 61.435,
#                  'word': 'sound'},
#                { 'end': 61.855,
#                  'score': 0.566,
#                  'speaker': 'SPEAKER_05',
#                  'start': 61.695,
#                  'word': 'like?'}]},
#   { 'end': 62.596,
#     'speaker': 'SPEAKER_05',
#     'start': 62.176,
#     'text': 'Babies.',
#     'words': [ { 'end': 62.596,
#                  'score': 0.837,
#                  'speaker': 'SPEAKER_05',
#                  'start': 62.176,
#                  'word': 'Babies.'}]},
#   { 'end': 64.679,
#     'speaker': 'SPEAKER_05',
#     'start': 62.977,
#     'text': 'Two whiny babies.',
#     'words': [ { 'end': 63.217,
#                  'score': 0.858,
#                  'speaker': 'SPEAKER_05',
#                  'start': 62.977,
#                  'word': 'Two'},
#                { 'end': 63.958,
#                  'score': 0.801,
#                  'speaker': 'SPEAKER_05',
#                  'start': 63.577,
#                  'word': 'whiny'},
#                { 'end': 64.679,
#                  'score': 0.822,
#                  'speaker': 'SPEAKER_05',
#                  'start': 64.218,
#                  'word': 'babies.'}]},
#   { 'end': 68.063,
#     'speaker': 'SPEAKER_05',
#     'start': 65.16,
#     'text': "There's nothing worse than being stuck with two whiny babies.",
#     'words': [ { 'end': 65.34,
#                  'score': 0.907,
#                  'speaker': 'SPEAKER_05',
#                  'start': 65.16,
#                  'word': "There's"},
#                { 'end': 65.6,
#                  'score': 0.881,
#                  'speaker': 'SPEAKER_05',
#                  'start': 65.36,
#                  'word': 'nothing'},
#                { 'end': 65.84,
#                  'score': 0.989,
#                  'speaker': 'SPEAKER_05',
#                  'start': 65.64,
#                  'word': 'worse'},
#                { 'end': 65.981,
#                  'score': 0.779,
#                  'speaker': 'SPEAKER_05',
#                  'start': 65.86,
#                  'word': 'than'},
#                { 'end': 66.161,
#                  'score': 0.66,
#                  'speaker': 'SPEAKER_05',
#                  'start': 66.001,
#                  'word': 'being'},
#                { 'end': 66.461,
#                  'score': 0.839,
#                  'speaker': 'SPEAKER_05',
#                  'start': 66.201,
#                  'word': 'stuck'},
#                { 'end': 66.601,
#                  'score': 0.781,
#                  'speaker': 'SPEAKER_05',
#                  'start': 66.481,
#                  'word': 'with'},
#                { 'end': 67.062,
#                  'score': 0.85,
#                  'speaker': 'SPEAKER_05',
#                  'start': 66.862,
#                  'word': 'two'},
#                { 'end': 67.543,
#                  'score': 0.833,
#                  'speaker': 'SPEAKER_05',
#                  'start': 67.202,
#                  'word': 'whiny'},
#                { 'end': 68.063,
#                  'score': 0.964,
#                  'speaker': 'SPEAKER_05',
#                  'start': 67.663,
#                  'word': 'babies.'}]},
#   { 'end': 85.451,
#     'speaker': 'SPEAKER_04',
#     'start': 84.011,
#     'text': " Oh, my God, I'm gonna have two babies.",
#     'words': [ { 'end': 84.111,
#                  'score': 0.627,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.011,
#                  'word': 'Oh,'},
#                { 'end': 84.231,
#                  'score': 0.686,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.131,
#                  'word': 'my'},
#                { 'end': 84.411,
#                  'score': 0.444,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.251,
#                  'word': 'God,'},
#                { 'end': 84.511,
#                  'score': 0.312,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.451,
#                  'word': "I'm"},
#                { 'end': 84.751,
#                  'score': 0.299,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.531,
#                  'word': 'gonna'},
#                { 'end': 84.911,
#                  'score': 0.873,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.791,
#                  'word': 'have'},
#                { 'end': 85.071,
#                  'score': 0.94,
#                  'speaker': 'SPEAKER_04',
#                  'start': 84.951,
#                  'word': 'two'},
#                { 'end': 85.451,
#                  'score': 0.898,
#                  'speaker': 'SPEAKER_04',
#                  'start': 85.111,
#                  'word': 'babies.'}]},
#   { 'end': 87.492,
#     'speaker': 'SPEAKER_05',
#     'start': 85.692,
#     'text': 'No, no, no, no, no, no.',
#     'words': [ { 'end': 85.832,
#                  'score': 0.694,
#                  'speaker': 'SPEAKER_04',
#                  'start': 85.692,
#                  'word': 'No,'},
#                { 'end': 86.332,
#                  'score': 0.853,
#                  'speaker': 'SPEAKER_05',
#                  'start': 85.912,
#                  'word': 'no,'},
#                { 'end': 86.972,
#                  'score': 0.67,
#                  'speaker': 'SPEAKER_05',
#                  'start': 86.732,
#                  'word': 'no,'},
#                { 'end': 87.132,
#                  'score': 0.355,
#                  'speaker': 'SPEAKER_05',
#                  'start': 87.032,
#                  'word': 'no,'},
#                { 'end': 87.292,
#                  'score': 0.646,
#                  'speaker': 'SPEAKER_05',
#                  'start': 87.172,
#                  'word': 'no,'},
#                { 'end': 87.492,
#                  'score': 0.769,
#                  'speaker': 'SPEAKER_05',
#                  'start': 87.352,
#                  'word': 'no.'}]},
#   { 'end': 88.652,
#     'speaker': 'SPEAKER_05',
#     'start': 87.552,
#     'text': 'Babies are great.',
#     'words': [ { 'end': 87.912,
#                  'score': 0.741,
#                  'speaker': 'SPEAKER_05',
#                  'start': 87.552,
#                  'word': 'Babies'},
#                { 'end': 88.232,
#                  'score': 0.433,
#                  'speaker': 'SPEAKER_05',
#                  'start': 88.052,
#                  'word': 'are'},
#                { 'end': 88.652,
#                  'score': 0.973,
#                  'speaker': 'SPEAKER_05',
#                  'start': 88.332,
#                  'word': 'great.'}]},
#   { 'end': 89.933,
#     'speaker': 'SPEAKER_05',
#     'start': 88.672,
#     'text': "You're lucky to have two babies.",
#     'words': [ { 'end': 88.853,
#                  'score': 0.82,
#                  'speaker': 'SPEAKER_05',
#                  'start': 88.672,
#                  'word': "You're"},
#                { 'end': 89.113,
#                  'score': 0.812,
#                  'speaker': 'SPEAKER_05',
#                  'start': 88.873,
#                  'word': 'lucky'},
#                { 'end': 89.253,
#                  'score': 0.824,
#                  'speaker': 'SPEAKER_05',
#                  'start': 89.153,
#                  'word': 'to'},
#                { 'end': 89.393,
#                  'score': 0.982,
#                  'speaker': 'SPEAKER_05',
#                  'start': 89.273,
#                  'word': 'have'},
#                { 'end': 89.573,
#                  'score': 0.99,
#                  'speaker': 'SPEAKER_05',
#                  'start': 89.453,
#                  'word': 'two'},
#                { 'end': 89.933,
#                  'score': 0.809,
#                  'speaker': 'SPEAKER_05',
#                  'start': 89.613,
#                  'word': 'babies.'}]},
#   { 'end': 90.773,
#     'speaker': 'SPEAKER_05',
#     'start': 90.133,
#     'text': 'I mean, look at me.',
#     'words': [ { 'end': 90.193,
#                  'score': 0.802,
#                  'speaker': 'SPEAKER_05',
#                  'start': 90.133,
#                  'word': 'I'},
#                { 'end': 90.333,
#                  'score': 0.911,
#                  'speaker': 'SPEAKER_05',
#                  'start': 90.233,
#                  'word': 'mean,'},
#                { 'end': 90.513,
#                  'score': 0.951,
#                  'speaker': 'SPEAKER_05',
#                  'start': 90.353,
#                  'word': 'look'},
#                { 'end': 90.593,
#                  'score': 0.522,
#                  'speaker': 'SPEAKER_05',
#                  'start': 90.533,
#                  'word': 'at'},
#                { 'end': 90.773,
#                  'score': 0.708,
#                  'speaker': 'SPEAKER_05',
#                  'start': 90.633,
#                  'word': 'me.'}]},
#   { 'end': 91.813,
#     'speaker': 'SPEAKER_05',
#     'start': 91.273,
#     'text': "I'm all alone.",
#     'words': [ { 'end': 91.393,
#                  'score': 0.887,
#                  'speaker': 'SPEAKER_05',
#                  'start': 91.273,
#                  'word': "I'm"},
#                { 'end': 91.553,
#                  'score': 0.83,
#                  'speaker': 'SPEAKER_05',
#                  'start': 91.433,
#                  'word': 'all'},
#                { 'end': 91.813,
#                  'score': 0.879,
#                  'speaker': 'SPEAKER_05',
#                  'start': 91.573,
#                  'word': 'alone.'}]},
#   { 'end': 93.214,
#     'speaker': 'SPEAKER_05',
#     'start': 91.873,
#     'text': "I'm never gonna have babies.",
#     'words': [ { 'end': 91.993,
#                  'score': 0.86,
#                  'speaker': 'SPEAKER_05',
#                  'start': 91.873,
#                  'word': "I'm"},
#                { 'end': 92.194,
#                  'score': 0.847,
#                  'speaker': 'SPEAKER_05',
#                  'start': 92.013,
#                  'word': 'never'},
#                { 'end': 92.474,
#                  'score': 0.238,
#                  'speaker': 'SPEAKER_05',
#                  'start': 92.214,
#                  'word': 'gonna'},
#                { 'end': 92.694,
#                  'score': 0.903,
#                  'speaker': 'SPEAKER_05',
#                  'start': 92.534,
#                  'word': 'have'},
#                { 'end': 93.214,
#                  'score': 0.699,
#                  'speaker': 'SPEAKER_05',
#                  'start': 92.774,
#                  'word': 'babies.'}]},
#   { 'end': 96.895,
#     'speaker': 'SPEAKER_05',
#     'start': 93.394,
#     'text': "Because you can't make a baby watching Netflix with your dog.",
#     'words': [ { 'end': 93.574,
#                  'score': 0.701,
#                  'speaker': 'SPEAKER_05',
#                  'start': 93.394,
#                  'word': 'Because'},
#                { 'end': 93.694,
#                  'score': 0.987,
#                  'speaker': 'SPEAKER_05',
#                  'start': 93.594,
#                  'word': 'you'},
#                { 'end': 93.994,
#                  'score': 0.727,
#                  'speaker': 'SPEAKER_05',
#                  'start': 93.714,
#                  'word': "can't"},
#                { 'end': 94.214,
#                  'score': 0.719,
#                  'speaker': 'SPEAKER_05',
#                  'start': 94.014,
#                  'word': 'make'},
#                { 'end': 94.314,
#                  'score': 0.14,
#                  'speaker': 'SPEAKER_05',
#                  'start': 94.254,
#                  'word': 'a'},
#                { 'end': 94.794,
#                  'score': 0.902,
#                  'speaker': 'SPEAKER_05',
#                  'start': 94.434,
#                  'word': 'baby'},
#                { 'end': 95.134,
#                  'score': 0.916,
#                  'speaker': 'SPEAKER_05',
#                  'start': 94.834,
#                  'word': 'watching'},
#                { 'end': 95.755,
#                  'score': 0.791,
#                  'speaker': 'SPEAKER_05',
#                  'start': 95.274,
#                  'word': 'Netflix'},
#                { 'end': 95.935,
#                  'score': 0.869,
#                  'speaker': 'SPEAKER_05',
#                  'start': 95.795,
#                  'word': 'with'},
#                { 'end': 96.135,
#                  'score': 0.821,
#                  'speaker': 'SPEAKER_05',
#                  'start': 95.955,
#                  'word': 'your'},
#                { 'end': 96.895,
#                  'score': 0.97,
#                  'speaker': 'SPEAKER_05',
#                  'start': 96.455,
#                  'word': 'dog.'}]},
#   { 'end': 103.617,
#     'speaker': 'SPEAKER_00',
#     'start': 102.877,
#     'text': 'Thanks for coming.',
#     'words': [ { 'end': 103.077,
#                  'score': 0.732,
#                  'speaker': 'SPEAKER_00',
#                  'start': 102.877,
#                  'word': 'Thanks'},
#                { 'end': 103.237,
#                  'score': 0.884,
#                  'speaker': 'SPEAKER_00',
#                  'start': 103.117,
#                  'word': 'for'},
#                { 'end': 103.617,
#                  'score': 0.712,
#                  'speaker': 'SPEAKER_00',
#                  'start': 103.277,
#                  'word': 'coming.'}]},
#   { 'end': 113.02,
#     'speaker': 'SPEAKER_03',
#     'start': 108.499,
#     'text': "Physics is all we're cut out for.",
#     'words': [ { 'end': 111.86,
#                  'score': 0.689,
#                  'speaker': 'SPEAKER_03',
#                  'start': 108.499,
#                  'word': 'Physics'},
#                { 'end': 112.02,
#                  'score': 0.496,
#                  'speaker': 'SPEAKER_03',
#                  'start': 111.9,
#                  'word': 'is'},
#                { 'end': 112.2,
#                  'score': 0.79,
#                  'speaker': 'SPEAKER_03',
#                  'start': 112.06,
#                  'word': 'all'},
#                { 'end': 112.34,
#                  'score': 0.578,
#                  'speaker': 'SPEAKER_03',
#                  'start': 112.22,
#                  'word': "we're"},
#                { 'end': 112.58,
#                  'score': 0.576,
#                  'speaker': 'SPEAKER_03',
#                  'start': 112.38,
#                  'word': 'cut'},
#                { 'end': 112.74,
#                  'score': 0.85,
#                  'speaker': 'SPEAKER_03',
#                  'start': 112.64,
# ...
#                  'start': 243.314,
#                  'word': 'do'},
#                { 'end': 243.994,
#                  'score': 0.97,
#                  'speaker': 'SPEAKER_02',
#                  'start': 243.574,
#                  'word': 'physics'},
#                { 'end': 244.214,
#                  'score': 0.763,
#                  'speaker': 'SPEAKER_02',
#                  'start': 244.054,
#                  'word': 'for'},
#                { 'end': 244.334,
#                  'score': 0.85,
#                  'speaker': 'SPEAKER_02',
#                  'start': 244.254,
#                  'word': 'the'},
#                { 'end': 244.994,
#                  'score': 0.901,
#                  'speaker': 'SPEAKER_02',
#                  'start': 244.414,
#                  'word': 'glory'},
#                { 'end': 245.175,
#                  'score': 0.928,
#                  'speaker': 'SPEAKER_02',
#                  'start': 245.115,
#                  'word': 'or'},
#                { 'end': 245.315,
#                  'score': 0.976,
#                  'speaker': 'SPEAKER_02',
#                  'start': 245.215,
#                  'word': 'the'},
#                { 'end': 246.035,
#                  'score': 0.823,
#                  'speaker': 'SPEAKER_02',
#                  'start': 245.375,
#                  'word': 'awards,'},
#                { 'end': 246.315,
#                  'score': 0.775,
#                  'speaker': 'SPEAKER_02',
#                  'start': 246.135,
#                  'word': 'but'},
#                { 'end': 246.775,
#                  'score': 0.826,
#                  'speaker': 'SPEAKER_02',
#                  'start': 246.635,
#                  'word': 'just'},
#                { 'end': 247.015,
#                  'score': 0.894,
#                  'speaker': 'SPEAKER_02',
#                  'start': 246.895,
#                  'word': 'for'},
#                { 'end': 247.115,
#                  'score': 0.826,
#                  'speaker': 'SPEAKER_02',
#                  'start': 247.035,
#                  'word': 'the'},
#                { 'end': 247.415,
#                  'score': 0.841,
#                  'speaker': 'SPEAKER_02',
#                  'start': 247.195,
#                  'word': 'fun'},
#                { 'end': 247.535,
#                  'score': 0.899,
#                  'speaker': 'SPEAKER_02',
#                  'start': 247.475,
#                  'word': 'of'},
#                { 'end': 247.695,
#                  'score': 0.999,
#                  'speaker': 'SPEAKER_02',
#                  'start': 247.655,
#                  'word': 'it.'}]},
#   { 'end': 250.235,
#     'speaker': 'SPEAKER_03',
#     'start': 249.755,
#     'text': " You're right.",
#     'words': [ { 'end': 249.895,
#                  'score': 0.083,
#                  'speaker': 'SPEAKER_03',
#                  'start': 249.755,
#                  'word': "You're"},
#                { 'end': 250.235,
#                  'score': 0.872,
#                  'speaker': 'SPEAKER_03',
#                  'start': 249.955,
#                  'word': 'right.'}]},
#   { 'end': 254.837,
#     'speaker': 'SPEAKER_03',
#     'start': 252.196,
#     'text': 'Physics is only dead when we stop being excited about it.',
#     'words': [ { 'end': 252.556,
#                  'score': 0.942,
#                  'speaker': 'SPEAKER_03',
#                  'start': 252.196,
#                  'word': 'Physics'},
#                { 'end': 252.736,
#                  'score': 0.493,
#                  'speaker': 'SPEAKER_03',
#                  'start': 252.636,
#                  'word': 'is'},
#                { 'end': 253.016,
#                  'score': 0.869,
#                  'speaker': 'SPEAKER_03',
#                  'start': 252.796,
#                  'word': 'only'},
#                { 'end': 253.236,
#                  'score': 0.927,
#                  'speaker': 'SPEAKER_03',
#                  'start': 253.056,
#                  'word': 'dead'},
#                { 'end': 253.416,
#                  'score': 0.789,
#                  'speaker': 'SPEAKER_03',
#                  'start': 253.276,
#                  'word': 'when'},
#                { 'end': 253.556,
#                  'score': 0.998,
#                  'speaker': 'SPEAKER_03',
#                  'start': 253.456,
#                  'word': 'we'},
#                { 'end': 253.857,
#                  'score': 0.796,
#                  'speaker': 'SPEAKER_03',
#                  'start': 253.596,
#                  'word': 'stop'},
#                { 'end': 254.037,
#                  'score': 0.886,
#                  'speaker': 'SPEAKER_03',
#                  'start': 253.877,
#                  'word': 'being'},
#                { 'end': 254.457,
#                  'score': 0.935,
#                  'speaker': 'SPEAKER_05',
#                  'start': 254.117,
#                  'word': 'excited'},
#                { 'end': 254.757,
#                  'score': 0.851,
#                  'speaker': 'SPEAKER_05',
#                  'start': 254.517,
#                  'word': 'about'},
#                { 'end': 254.837,
#                  'score': 0.996,
#                  'speaker': 'SPEAKER_05',
#                  'start': 254.797,
#                  'word': 'it.'}]},
#   { 'end': 258.999,
#     'speaker': 'SPEAKER_05',
#     'start': 256.478,
#     'text': "Even beyond the grave, he's imparting wisdom.",
#     'words': [ { 'end': 256.678,
#                  'score': 0.874,
#                  'speaker': 'SPEAKER_05',
#                  'start': 256.478,
#                  'word': 'Even'},
#                { 'end': 257.018,
#                  'score': 0.811,
#                  'speaker': 'SPEAKER_05',
#                  'start': 256.718,
#                  'word': 'beyond'},
#                { 'end': 257.138,
#                  'score': 0.922,
#                  'speaker': 'SPEAKER_05',
#                  'start': 257.058,
#                  'word': 'the'},
#                { 'end': 257.478,
#                  'score': 0.925,
#                  'speaker': 'SPEAKER_05',
#                  'start': 257.198,
#                  'word': 'grave,'},
#                { 'end': 257.918,
#                  'score': 0.807,
#                  'speaker': 'SPEAKER_05',
#                  'start': 257.738,
#                  'word': "he's"},
#                { 'end': 258.478,
#                  'score': 0.84,
#                  'speaker': 'SPEAKER_05',
#                  'start': 257.998,
#                  'word': 'imparting'},
#                { 'end': 258.999,
#                  'score': 0.925,
#                  'speaker': 'SPEAKER_05',
#                  'start': 258.538,
#                  'word': 'wisdom.'}]},
#   { 'end': 261.62,
#     'speaker': 'SPEAKER_05',
#     'start': 259.019,
#     'text': "Um, I'm the one who remembered it.",
#     'words': [ { 'end': 259.939,
#                  'score': 0.85,
#                  'speaker': 'SPEAKER_05',
#                  'start': 259.019,
#                  'word': 'Um,'},
#                { 'end': 260.539,
#                  'score': 0.877,
#                  'speaker': 'SPEAKER_05',
#                  'start': 260.419,
#                  'word': "I'm"},
#                { 'end': 260.679,
#                  'score': 0.865,
#                  'speaker': 'SPEAKER_05',
#                  'start': 260.599,
#                  'word': 'the'},
#                { 'end': 260.879,
#                  'score': 0.845,
#                  'speaker': 'SPEAKER_05',
#                  'start': 260.779,
#                  'word': 'one'},
#                { 'end': 261.059,
#                  'score': 0.751,
#                  'speaker': 'SPEAKER_05',
#                  'start': 260.919,
#                  'word': 'who'},
#                { 'end': 261.5,
#                  'score': 0.878,
#                  'speaker': 'SPEAKER_05',
#                  'start': 261.099,
#                  'word': 'remembered'},
#                { 'end': 261.62,
#                  'score': 0.793,
#                  'speaker': 'SPEAKER_05',
#                  'start': 261.56,
#                  'word': 'it.'}]},
#   { 'end': 265.021,
#     'speaker': 'SPEAKER_04',
#     'start': 264.381,
#     'text': 'Give me the bottle.',
#     'words': [ { 'end': 264.481,
#                  'score': 0.267,
#                  'speaker': 'SPEAKER_04',
#                  'start': 264.381,
#                  'word': 'Give'},
#                { 'end': 264.601,
#                  'score': 0.589,
#                  'speaker': 'SPEAKER_04',
#                  'start': 264.501,
#                  'word': 'me'},
#                { 'end': 264.701,
#                  'score': 0.788,
#                  'speaker': 'SPEAKER_04',
#                  'start': 264.621,
#                  'word': 'the'},
#                { 'end': 265.021,
#                  'score': 0.833,
#                  'speaker': 'SPEAKER_04',
#                  'start': 264.721,
#                  'word': 'bottle.'}]},
#   { 'end': 271.343,
#     'speaker': 'SPEAKER_04',
#     'start': 265.341,
#     'text': 'It might be a little corny, but I say we pour one out for all the '
#             'science homies who came before us.',
#     'words': [ { 'end': 265.441,
#                  'score': 0.58,
#                  'speaker': 'SPEAKER_04',
#                  'start': 265.341,
#                  'word': 'It'},
#                { 'end': 265.641,
#                  'score': 0.907,
#                  'speaker': 'SPEAKER_04',
#                  'start': 265.481,
#                  'word': 'might'},
#                { 'end': 265.741,
#                  'score': 0.82,
#                  'speaker': 'SPEAKER_04',
#                  'start': 265.661,
#                  'word': 'be'},
#                { 'end': 265.781,
#                  'score': 0.994,
#                  'speaker': 'SPEAKER_04',
#                  'start': 265.761,
#                  'word': 'a'},
#                { 'end': 266.001,
#                  'score': 0.882,
#                  'speaker': 'SPEAKER_04',
#                  'start': 265.821,
#                  'word': 'little'},
#                { 'end': 266.341,
#                  'score': 0.983,
#                  'speaker': 'SPEAKER_04',
#                  'start': 266.061,
#                  'word': 'corny,'},
#                { 'end': 266.502,
#                  'score': 0.817,
#                  'speaker': 'SPEAKER_04',
#                  'start': 266.361,
#                  'word': 'but'},
#                { 'end': 266.702,
#                  'score': 0.662,
#                  'speaker': 'SPEAKER_04',
#                  'start': 266.602,
#                  'word': 'I'},
#                { 'end': 267.002,
#                  'score': 0.857,
#                  'speaker': 'SPEAKER_04',
#                  'start': 266.762,
#                  'word': 'say'},
#                { 'end': 267.282,
#                  'score': 0.891,
#                  'speaker': 'SPEAKER_04',
#                  'start': 267.122,
#                  'word': 'we'},
#                { 'end': 267.582,
#                  'score': 0.892,
#                  'speaker': 'SPEAKER_04',
#                  'start': 267.322,
#                  'word': 'pour'},
#                { 'end': 267.762,
#                  'score': 0.853,
#                  'speaker': 'SPEAKER_04',
#                  'start': 267.682,
#                  'word': 'one'},
#                { 'end': 268.042,
#                  'score': 0.935,
#                  'speaker': 'SPEAKER_04',
#                  'start': 267.902,
#                  'word': 'out'},
#                { 'end': 268.322,
#                  'score': 0.997,
#                  'speaker': 'SPEAKER_04',
#                  'start': 268.142,
#                  'word': 'for'},
#                { 'end': 268.622,
#                  'score': 0.87,
#                  'speaker': 'SPEAKER_04',
#                  'start': 268.462,
#                  'word': 'all'},
#                { 'end': 268.862,
#                  'score': 0.888,
#                  'speaker': 'SPEAKER_04',
#                  'start': 268.682,
#                  'word': 'the'},
#                { 'end': 269.643,
#                  'score': 0.806,
#                  'speaker': 'SPEAKER_04',
#                  'start': 269.143,
#                  'word': 'science'},
#                { 'end': 270.263,
#                  'score': 0.713,
#                  'speaker': 'SPEAKER_04',
#                  'start': 269.723,
#                  'word': 'homies'},
#                { 'end': 270.483,
#                  'score': 0.947,
#                  'speaker': 'SPEAKER_04',
#                  'start': 270.323,
#                  'word': 'who'},
#                { 'end': 270.743,
#                  'score': 0.985,
#                  'speaker': 'SPEAKER_04',
#                  'start': 270.523,
#                  'word': 'came'},
#                { 'end': 271.143,
#                  'score': 0.837,
#                  'speaker': 'SPEAKER_04',
#                  'start': 270.803,
#                  'word': 'before'},
#                { 'end': 271.343,
#                  'score': 0.933,
#                  'speaker': 'SPEAKER_04',
#                  'start': 271.263,
#                  'word': 'us.'}]},
#   { 'end': 272.104,
#     'speaker': 'SPEAKER_04',
#     'start': 271.643,
#     'text': 'I love that.',
#     'words': [ { 'end': 271.724,
#                  'score': 0.824,
#                  'speaker': 'SPEAKER_04',
#                  'start': 271.643,
#                  'word': 'I'},
#                { 'end': 271.944,
#                  'score': 0.952,
#                  'speaker': 'SPEAKER_04',
#                  'start': 271.764,
#                  'word': 'love'},
#                { 'end': 272.104,
#                  'score': 0.336,
#                  'speaker': 'SPEAKER_04',
#                  'start': 271.964,
#                  'word': 'that.'}]},
#   { 'end': 272.484,
#     'speaker': 'SPEAKER_04',
#     'start': 272.124,
#     'text': "Let's do it.",
#     'words': [ { 'end': 272.224,
#                  'score': 0.017,
#                  'speaker': 'SPEAKER_04',
#                  'start': 272.124,
#                  'word': "Let's"},
#                { 'end': 272.364,
#                  'score': 0.634,
#                  'speaker': 'SPEAKER_04',
#                  'start': 272.244,
#                  'word': 'do'},
#                { 'end': 272.484,
#                  'score': 0.714,
#                  'speaker': 'SPEAKER_04',
#                  'start': 272.444,
#                  'word': 'it.'}]},
#   { 'end': 279.988,
#     'speaker': 'SPEAKER_02',
#     'start': 279.087,
#     'text': ' Here comes some more.',
#     'words': [ { 'end': 279.227,
#                  'score': 0.375,
#                  'speaker': 'SPEAKER_02',
#                  'start': 279.087,
#                  'word': 'Here'},
#                { 'end': 279.488,
#                  'score': 0.892,
#                  'speaker': 'SPEAKER_02',
#                  'start': 279.247,
#                  'word': 'comes'},
#                { 'end': 279.648,
#                  'score': 0.386,
#                  'speaker': 'SPEAKER_02',
#                  'start': 279.528,
#                  'word': 'some'},
#                { 'end': 279.988,
#                  'score': 0.712,
#                  'speaker': 'SPEAKER_02',
#                  'start': 279.668,
#                  'word': 'more.'}]},
#   { 'end': 286.478,
#     'speaker': 'SPEAKER_00',
#     'start': 285.536,
#     'text': 'We got to see him run.',
#     'words': [ { 'end': 285.636,
#                  'score': 0.942,
#                  'speaker': 'SPEAKER_00',
#                  'start': 285.536,
#                  'word': 'We'},
#                { 'end': 285.797,
#                  'score': 0.816,
#                  'speaker': 'SPEAKER_00',
#                  'start': 285.677,
#                  'word': 'got'},
#                { 'end': 285.877,
#                  'score': 0.736,
#                  'speaker': 'SPEAKER_00',
#                  'start': 285.817,
#                  'word': 'to'},
#                { 'end': 286.057,
#                  'score': 0.848,
#                  'speaker': 'SPEAKER_00',
#                  'start': 285.917,
#                  'word': 'see'},
#                { 'end': 286.177,
#                  'score': 0.665,
#                  'speaker': 'SPEAKER_00',
#                  'start': 286.097,
#                  'word': 'him'},
#                { 'end': 286.478,
#                  'score': 0.886,
#                  'speaker': 'SPEAKER_00',
#                  'start': 286.217,
#                  'word': 'run.'}]}]

# %% [markdown]
# # **Convert and print the conversation style**

# %%
import re

# Format the output
conversation = []  # List to hold the formatted conversation
for segment in result["segments"]:
    speaker_id_str = segment.get("speaker", "Unknown")  # Get the speaker ID, default to "Unknown" if not present
    text = segment.get("text", "").strip()  # Get the transcribed text and strip whitespace

    # Extract the numeric part of the speaker ID (e.g., from 'SPEAKER_01' to '01')
    speaker_id_match = re.search(r'(\d+)', speaker_id_str)
    if speaker_id_match:
        speaker_id = int(speaker_id_match.group(1))  # Convert the extracted number to an integer
        # Create a speaker label (e.g., Speaker A, Speaker B)
        speaker_label = f"Speaker {chr(65 + speaker_id)}"  # Converts 0 -> 'A', 1 -> 'B', etc.
        # Append the formatted text to the conversation list
        conversation.append(f"{speaker_label}: {text}")
    else:
        # Handle the case where no valid speaker ID is found, if necessary
        continue

# Convert the conversation list to a single paragraph
paragraph = "\n".join(conversation)

# Print the formatted conversation as a paragraph
print("\nFormatted conversation in paragraph format:")
print(paragraph)
# Out:
# Formatted conversation in paragraph format:
# Speaker A: Okay, so you guys are upset because the Collider thing disproved your theories?
# Speaker D: It's worse than that.
# Speaker D: It hasn't found anything in years, so we don't know if we're right, we don't know if we're wrong, we don't know where to go next.
# Speaker C: All I know is it looks like I tongue-kissed Avatar.
# Speaker A: Come on, you guys are physicists.
# Speaker A: Okay, you're always gonna be physicists.
# Speaker A: And sure, sometimes the physics is hard, but isn't that what makes it boring?
# Speaker A: Hey.
# Speaker E: We're here.
# Speaker E: What's going on?
# Speaker A: Okay, as far as I can see, science is dead because Leonard killed it.
# Speaker A: And I don't know who the Romulans are, but those guys know how to party.
# Speaker A: So what do you want us to do?
# Speaker A: I don't know.
# Speaker A: You're scientists.
# Speaker A: Cheer them up.
# Speaker E: Cheer them up?
# Speaker E: Do you even know what a scientist is?
# Speaker D: But we don't need to be cheered up.
# Speaker D: It just turns out that physics is exactly like Lost.
# Speaker D: Started out great and turns out just a big old waste of time.
# Speaker B: Boo-hoo.
# Speaker F: You know what you sound like?
# Speaker F: Babies.
# Speaker F: Two whiny babies.
# Speaker F: There's nothing worse than being stuck with two whiny babies.
# Speaker E: Oh, my God, I'm gonna have two babies.
# Speaker F: No, no, no, no, no, no.
# Speaker F: Babies are great.
# Speaker F: You're lucky to have two babies.
# Speaker F: I mean, look at me.
# Speaker F: I'm all alone.
# Speaker F: I'm never gonna have babies.
# Speaker F: Because you can't make a baby watching Netflix with your dog.
# Speaker A: Thanks for coming.
# Speaker D: Physics is all we're cut out for.
# Speaker D: If we weren't physicists, what would we be?
# Speaker D: I don't know.
# Speaker D: Popular?
# Speaker C: It's fine.
# Speaker C: I don't need to be a theoretical physicist.
# Speaker C: There's lots of things I could use this brain for.
# Speaker C: I could be an accountant for the mob.
# Speaker C: I could guess people's weight at the fair.
# Speaker A: Okay, this is getting silly.
# Speaker C: Is it? 180.
# Speaker A: Okay, that is enough.
# Speaker A: Your lives are not wasted.
# Speaker A: Your careers are not at a dead end.
# Speaker A: You just hit a rough patch.
# Speaker A: Instead of feeling sorry for yourselves, you need to get up and get inspired.
# Speaker D: How?
# Speaker A: I don't know.
# Speaker A: You know, when I'm feeling down, I go for a run, which is exactly why I'm not 180 pounds, genius.
# Speaker D: I know where we need to go.
# Speaker D: Are we running there?
# Speaker D: Because watching drunk children run would be the highlight of my life.
# Speaker C: We're going to see Richard Feynman.
# Speaker C: Penny, Richard Feynman is an iconic physicist.
# Speaker A: I know who he is.
# Speaker A: Leonard dressed as him for Halloween last year.
# Speaker A: I had no idea Richard Feynman was dead.
# Speaker E: Most people don't know.
# Speaker E: He's actually buried right here in Altadena.
# Speaker C: I'm sure they keep a lid on that to avoid traffic jams.
# Speaker F: Here he is.
# Speaker A: Oh, wow.
# Speaker A: He's buried with his wife.
# Speaker F: We get it.
# Speaker F: A lady loved you.
# Speaker F: Quit bragging.
# Speaker D: Iman was so cool.
# Speaker D: When I was a kid, I'd put on some headphones and crank up one of his lectures and just jam out to knowledge.
# Speaker E: This guy knew how to live.
# Speaker E: Taught himself musical instruments.
# Speaker E: Studied Portuguese.
# Speaker F: Used to give a speech in Brazil.
# Speaker F: The only part of me that's been to Brazil is my bikini line.
# Speaker D: He did so much.
# Speaker D: And here we are, stuck and letting him down.
# Speaker C: You know, Feynman used to say he didn't do physics for the glory or the awards, but just for the fun of it.
# Speaker D: You're right.
# Speaker D: Physics is only dead when we stop being excited about it.
# Speaker F: Even beyond the grave, he's imparting wisdom.
# Speaker F: Um, I'm the one who remembered it.
# Speaker E: Give me the bottle.
# Speaker E: It might be a little corny, but I say we pour one out for all the science homies who came before us.
# Speaker E: I love that.
# Speaker E: Let's do it.
# Speaker C: Here comes some more.
# Speaker A: We got to see him run.
